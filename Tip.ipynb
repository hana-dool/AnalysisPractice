# %% [markdown]
# # Github 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 첫 시작시에 아래 코드를 실행한다. 
# !git clone https://hana-dool:(access token)@github.com/hana-dool/Analysis.git

# %%
cd /content/drive/MyDrive/Analysis
# Out:
# /content/drive/MyDrive/Analysis

# %%
# !git config --global user.email 'gorany131@gmail.com'
# !git config --global user.name 'hana-dool'

# %%
# !git add .

# %%
# !git commit -m '20221029'
# !git push
# Out:
# [main 12dd0b0] 20221029
#  4 files changed, 1731 insertions(+)
#  create mode 100644 "20221029 \341\204\220\341\205\241\341\204\213\341\205\265\341\204\220\341\205\241\341\204\202\341\205\265\341\206\250/data/submission.csv"
#  create mode 100644 "20221029 \341\204\220\341\205\241\341\204\213\341\205\265\341\204\220\341\205\241\341\204\202\341\205\265\341\206\250/data/test.csv"
#  create mode 100644 "20221029 \341\204\220\341\205\241\341\204\213\341\205\265\341\204\220\341\205\241\341\204\202\341\205\265\341\206\250/data/train.csv"
#  create mode 100644 gitupload.ipynb
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (8/8), 34.19 KiB | 2.44 MiB/s, done.
# Total 8 (delta 0), reused 0 (delta 0)
# To https://github.com/hana-dool/Analysis.git
#    5817a44..12dd0b0  main -> main

# %% [markdown]
# # Vscode 연결
# - 아직 적용하지 않았음

# %%
# 아래의 토큰은 https://dashboard.ngrok.com/get-started/setup ngrok 에 가입한뒤에 받은것
# vscode 로 편집할 수 있도록 해준다. (local에서)
NGROK_TOKEN = '2GnPpAefJ3AjAKCL2F9E5iRoMA8_6WeMY7PZKMpHsWxdMBxzP' 
PASSWORD = "123123"

# %%
# pip install colabcode ;

# %%
from colabcode import ColabCode
ColabCode(authtoken =NGROK_TOKEN, password =PASSWORD )
