# %% [markdown]
# # Note
# - graph 의 타당성을 체크하는 메서드이긴 한데, 이걸 잘 쓸지는 의문
# - d - seperation 을 이루는 모든 쌍에 대해서 independence test 를 수행하고 , 하나라도 만족 못하면 False 인데 너무 빡빡한거? 아닌지...

# %%
# !pip install dowhy
# pygraphviz install 
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dowhy
#   Downloading dowhy-0.8-py3-none-any.whl (287 kB)
#      |████████████████████████████████| 287 kB 6.4 MB/s
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from dowhy) (1.3.5)
# Collecting pydot>=1.4
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from dowhy) (1.21.6)
# Requirement already satisfied: sympy>=1.4 in /usr/local/lib/python3.7/dist-packages (from dowhy) (1.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from dowhy) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dowhy) (1.7.3)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from dowhy) (2.6.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from dowhy) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->dowhy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->dowhy) (2022.6)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot>=1.4->dowhy) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->dowhy) (1.15.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.4->dowhy) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->dowhy) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->dowhy) (1.2.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels->dowhy) (0.5.3)
# Installing collected packages: pydot, dowhy
#   Attempting uninstall: pydot
#     Found existing installation: pydot 1.3.0
#     Uninstalling pydot-1.3.0:
#       Successfully uninstalled pydot-1.3.0
# Successfully installed dowhy-0.8 pydot-1.4.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgvc6-plugins-gtk libxdot4
# 0 upgraded, 8 newly installed, 0 to remove and 5 not upgraded.
# Need to get 2,120 kB of archives.
# After this operation, 7,128 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxdot4 amd64 2.40.1-2 [15.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgvc6-plugins-gtk amd64 2.40.1-2 [18.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgraphviz-dev amd64 2.40.1-2 [57.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Fetched 2,120 kB in 2s (1,324 kB/s)
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 123991 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libxdot4.
# Preparing to unpack .../4-libxdot4_2.40.1-2_amd64.deb ...
# Unpacking libxdot4 (2.40.1-2) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.40.1-2_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.40.1-2) ...
# Selecting previously unselected package libgraphviz-dev.
# Preparing to unpack .../6-libgraphviz-dev_2.40.1-2_amd64.deb ...
# Unpacking libgraphviz-dev (2.40.1-2) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up libxdot4 (2.40.1-2) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgvc6-plugins-gtk (2.40.1-2) ...
# Setting up libgraphviz-dev (2.40.1-2) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygraphviz
#   Downloading pygraphviz-1.7.zip (118 kB)
#      |████████████████████████████████| 118 kB 6.5 MB/s
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.7-cp37-cp37m-linux_x86_64.whl size=165756 sha256=dbfb34a41c609bdb5d38c26e38c7259d18a122e2f292ad90d4ee6a1cfc7d105b
#   Stored in directory: /root/.cache/pip/wheels/8c/bc/0c/ac35392b72556e75107ff610cb31b313e8471918a6d280e34c
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.7

# %%
import numpy as np
import pandas as pd
import os, sys
import dowhy
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# randomly generated directed graph 를 만들어내는 method
from dowhy import datasets
# prob_type_of_data : 3-element tuple containing the probability of data being discrete, binary and continuous respectively.(Should add up to 1)
# num_vars : Number of variables in the dataset 
# num_samples: Number of samples in the dataset 
#  prob_edge : Probability of an edge between two random nodes in a graph 
#  random_seed: Seed for generating random graph
data = datasets.dataset_from_random_graph(num_vars = 10,
                                                num_samples = 5000,
                                                prob_edge = 0.3,
                                                random_seed = 100,
                                                prob_type_of_data = (0.333, 0.333, 0.334))
df = data["df"] #Insert dataset here
print(data["discrete_columns"], data["continuous_columns"], data["binary_columns"])
print(df.head())
# Out:
# ['a', 'c', 'e', 'f', 'h'] ['b', 'd', 'g', 'i', 'j'] ['c', 'e']
#    a         b  c         d  e  f         g  h         i         j
# 0 -1 -1.170054  1  0.996507  1  0 -0.218214 -1 -1.107993  0.699933
# 1  0  0.527130  1  0.894435  1  1  1.485562  0 -1.450727 -1.055649
# 2  0  0.436049  0 -0.151908  0  0  0.195296  0  2.280391  1.162284
# 3  0  0.005213  1  0.347139  1  0 -0.727156 -1 -1.140999 -2.165819
# 4  0  1.212397  0 -1.230150  0  1  0.582913  0 -1.377051 -2.359753

# %%
print(data["discrete_columns"], data["continuous_columns"], data["binary_columns"])
# Out:
# ['a', 'c', 'e', 'f', 'h'] ['b', 'd', 'g', 'i', 'j'] ['c', 'e']

# %%
graph_string = """graph [
  directed 1
  node [
    id 0
    label "a"
  ]
  node [
    id 1
    label "b"
  ]
  node [
    id 2
    label "c"
  ]
  node [
    id 3
    label "d"
  ]
  node [
    id 4
    label "e"
  ]
  node [
    id 5
    label "f"
  ]
  node [
    id 6
    label "g"
  ]
  node [
    id 7
    label "h"
  ]
  node [
    id 8
    label "i"
  ]
  node [
    id 9
    label "j"
  ]
  edge [
    source 0
    target 1
  ]
  edge [
    source 0
    target 8
  ]
  edge [
    source 1
    target 2
  ]
  edge [
    source 1
    target 5
  ]
  edge [
    source 2
    target 3
  ]
  edge [
    source 2
    target 4
  ]
  edge [
    source 3
    target 4
  ]
  edge [
    source 4
    target 5
  ]
  edge [
    source 5
    target 6
  ]
  edge [
    source 6
    target 7
  ]
  edge [
    source 7
    target 8
  ]
  edge [
    source 8
    target 9
  ]
]
"""

# %%
from dowhy import CausalModel
import dowhy.datasets

# %%
model=CausalModel(
        data = df,
        treatment=data["treatment_name"],
        outcome=data["outcome_name"],
        graph=graph_string
        )
model.view_model()
from IPython.display import Image, display
display(Image(filename="causal_model.png"))

# %% [markdown]
# We can check if the assumptions of the graph hold true for the data using model.refute_graph(k, independence_test = {'test_for_continuous': 'partial_correlation', 'test_for_discrete' : 'conditional_mutual_information'})
# - We are testing X ⫫ Y | Z where X and Y are singular sets and Z can have k number of variables.
# - k value is 1 by default unless input.
# - Currently we are using following settings
#     - “partial_correlation” for continuous data
#     - “conditional_mutual_information” for discrete data
#     - “conditional_mutua_information” when Z is discrete and either of X and Y is continuous
#     - “partial_correlation” when Z is continuous/binary and X and Y are either continuous/binary
#     - “conditional_mutual_information” when X and Y are discrete and Z has mixed data
# - other settings are currently not supported

# %%
refuter_object = model.refute_graph(k=1,
                                    independence_test = {'test_for_continuous': 'partial_correlation', 'test_for_discrete' : 'conditional_mutual_information'}) 
# Change k parameter to test conditional independence given different number of variables
# Out:
# The following setting with j as continuous, f as discrete, ('i',) as ['continuous'] not supported
# The following setting with j as continuous, a as discrete, ('i',) as ['continuous'] not supported
# The following setting with j as continuous, h as discrete, ('i',) as ['continuous'] not supported
# The following setting with d as continuous, g as continuous, ('f',) as ['discrete'] not supported
# The following setting with d as continuous, a as discrete, ('b',) as ['continuous'] not supported
# The following setting with d as continuous, h as discrete, ('g',) as ['continuous'] not supported
# The following setting with b as continuous, g as continuous, ('f',) as ['discrete'] not supported
# The following setting with b as continuous, h as discrete, ('g',) as ['continuous'] not supported
# The following setting with g as continuous, a as discrete, ('b',) as ['continuous'] not supported
# WARNING:dowhy.causal_refuters.graph_refuter:Some tests could not be run : config not supported

# %%
print(refuter_object)
# Out:
# Method name for discrete data:conditional_mutual_information
# Method name for continuous data:partial_correlation
# Number of conditional independencies entailed by model:235
# Number of independences satisfied by data:119
# Test passed:True

# %%
refuter_object = model.refute_graph(independence_constraints = [('c', 'e' , ('g',)), # c and e - binary, g - continuous
                                                                ('f', 'h' , ('b',)), # f and h - discrete, b - continuous
                                                                ('e', 'g' , ('h',)), # e - binary, g - continuous, h - discrete
                                                                ('c', 'a' , ('b',)), # c and a - discrete, b - continuous
                                                                ('d', 'i' , ('c',)), # d and i - continuous, c - binary
                                                                ('a', 'j' , ())      # a - discrete, j - continuous
                                                               ],
                         independence_test = {'test_for_continuous': 'partial_correlation', 'test_for_discrete' : 'conditional_mutual_information'}
                        )

# %%
print(refuter_object)
# Out:
# Method name for discrete data:conditional_mutual_information
# Method name for continuous data:partial_correlation
# Number of conditional independencies entailed by model:6
# Number of independences satisfied by data:6
# Test passed:True

# %%
graph_string = """graph [
        directed 1
        node [
            id 0
            label "a"
        ]
        node [
            id 1
            label "b"
        ]
        node [
            id 2
            label "c"
        ]
        node [
            id 3
            label "d"
        ]
        node [
            id 4
            label "e"
        ]
        node [
            id 5
            label "f"
        ]
        node [
            id 6
            label "g"
        ]
        node [
            id 7
            label "h"
        ]
        node [
            id 8
            label "i"
        ]
        node [
            id 9
            label "j"
        ]
        edge [
            source 0
            target 1
        ]
        edge [
            source 0
            target 2
        ]
        edge [
            source 0
            target 3
        ]
        edge [
            source 1
            target 4
        ]
        edge [
            source 1
            target 5
        ]
        edge [
            source 2
            target 3
        ]
        edge [
            source 4
            target 2
        ]
        edge [
            source 4
            target 5
        ]
        edge [
            source 4
            target 6
        ]
        edge [
            source 4
            target 7
        ]
        edge [
            source 8
            target 6
        ]
        edge
        [
        source 9
        target 0
        ]
        ]"""

# %%
model = CausalModel(
            data=df,
            treatment=data["treatment_name"],
            outcome=data["outcome_name"],
            graph=graph_string,
        )
model.view_model()
from IPython.display import Image, display
display(Image(filename="causal_model.png"))

# %%
refuter_object = model.refute_graph(k=1, independence_test = {'test_for_continuous': 'partial_correlation', 'test_for_discrete' : 'conditional_mutual_information'}) #Change k parameter to test conditional independence given different number of variables
# Out:
# The following setting with j as continuous, d as continuous, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, d as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, d as continuous, ('f', 'a') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, d as continuous, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, d as continuous, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, d as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with j as continuous, d as continuous, ('a', 'h') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, b as continuous, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, b as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, b as continuous, ('f', 'a') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, b as continuous, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, b as continuous, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, b as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with j as continuous, b as continuous, ('a', 'h') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, e as binary, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, e as binary, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, e as binary, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, e as binary, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, e as binary, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, e as binary, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, f as discrete, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, f as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with j as continuous, f as discrete, ('b', 'g') as ['continuous', 'continuous'] not supported
# The following setting with j as continuous, f as discrete, ('b', 'i') as ['continuous', 'continuous'] not supported
# The following setting with j as continuous, f as discrete, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, f as discrete, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, f as discrete, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, f as discrete, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('e', 'f') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('e', 'h') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('f', 'a') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, g as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with j as continuous, g as continuous, ('a', 'h') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('d', 'f') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('d', 'h') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('e', 'f') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('e', 'h') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('f', 'a') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('f', 'c') as ['discrete', 'binary'] not supported
# The following setting with j as continuous, i as continuous, ('f', 'h') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with j as continuous, i as continuous, ('a', 'h') as ['discrete', 'discrete'] not supported
# The following setting with j as continuous, i as continuous, ('c', 'h') as ['binary', 'discrete'] not supported
# The following setting with j as continuous, c as binary, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, c as binary, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, c as binary, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, c as binary, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, h as discrete, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with j as continuous, h as discrete, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, h as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with j as continuous, h as discrete, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, h as discrete, ('b', 'g') as ['continuous', 'continuous'] not supported
# The following setting with j as continuous, h as discrete, ('b', 'i') as ['continuous', 'continuous'] not supported
# The following setting with j as continuous, h as discrete, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, h as discrete, ('e', 'g') as ['binary', 'continuous'] not supported
# The following setting with j as continuous, h as discrete, ('e', 'i') as ['binary', 'continuous'] not supported
# The following setting with j as continuous, h as discrete, ('g', 'a') as ['continuous', 'discrete'] not supported
# The following setting with j as continuous, h as discrete, ('i', 'a') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, b as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, b as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with d as continuous, f as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with d as continuous, g as continuous, ('e', 'f') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, g as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, g as continuous, ('e', 'h') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, g as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with d as continuous, i as continuous, ('j', 'f') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('j', 'a') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('j', 'h') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('e', 'f') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('e', 'h') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('f', 'a') as ['discrete', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('f', 'c') as ['discrete', 'binary'] not supported
# The following setting with d as continuous, i as continuous, ('f', 'h') as ['discrete', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with d as continuous, i as continuous, ('a', 'h') as ['discrete', 'discrete'] not supported
# The following setting with d as continuous, i as continuous, ('c', 'h') as ['binary', 'discrete'] not supported
# The following setting with d as continuous, h as discrete, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with d as continuous, h as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with d as continuous, h as discrete, ('e', 'g') as ['binary', 'continuous'] not supported
# The following setting with d as continuous, h as discrete, ('e', 'i') as ['binary', 'continuous'] not supported
# The following setting with b as continuous, g as continuous, ('e', 'f') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, g as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, g as continuous, ('e', 'h') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('j', 'f') as ['continuous', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('j', 'a') as ['continuous', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('j', 'h') as ['continuous', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('d', 'f') as ['continuous', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('d', 'h') as ['continuous', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('e', 'f') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('e', 'a') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('e', 'h') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('f', 'a') as ['discrete', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('f', 'c') as ['discrete', 'binary'] not supported
# The following setting with b as continuous, i as continuous, ('f', 'h') as ['discrete', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('a', 'c') as ['discrete', 'binary'] not supported
# The following setting with b as continuous, i as continuous, ('a', 'h') as ['discrete', 'discrete'] not supported
# The following setting with b as continuous, i as continuous, ('c', 'h') as ['binary', 'discrete'] not supported
# The following setting with b as continuous, h as discrete, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with b as continuous, h as discrete, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with b as continuous, h as discrete, ('e', 'g') as ['binary', 'continuous'] not supported
# The following setting with b as continuous, h as discrete, ('e', 'i') as ['binary', 'continuous'] not supported
# The following setting with e as binary, i as continuous, ('j', 'f') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('j', 'a') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('j', 'h') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('d', 'f') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('d', 'h') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with e as binary, i as continuous, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, g as continuous, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, g as continuous, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, g as continuous, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, g as continuous, ('e', 'i') as ['binary', 'continuous'] not supported
# The following setting with f as discrete, i as continuous, ('j', 'd') as ['continuous', 'continuous'] not supported
# The following setting with f as discrete, i as continuous, ('j', 'b') as ['continuous', 'continuous'] not supported
# The following setting with f as discrete, i as continuous, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, i as continuous, ('j', 'a') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, i as continuous, ('j', 'c') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, i as continuous, ('j', 'h') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, i as continuous, ('d', 'b') as ['continuous', 'continuous'] not supported
# The following setting with f as discrete, i as continuous, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, i as continuous, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, i as continuous, ('d', 'c') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, i as continuous, ('d', 'h') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, i as continuous, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, i as continuous, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, i as continuous, ('b', 'c') as ['continuous', 'binary'] not supported
# The following setting with f as discrete, i as continuous, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with f as discrete, i as continuous, ('e', 'g') as ['binary', 'continuous'] not supported
# The following setting with g as continuous, a as discrete, ('j', 'b') as ['continuous', 'continuous'] not supported
# The following setting with g as continuous, a as discrete, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with g as continuous, a as discrete, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with g as continuous, a as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with g as continuous, a as discrete, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with g as continuous, a as discrete, ('b', 'i') as ['continuous', 'continuous'] not supported
# The following setting with g as continuous, a as discrete, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with g as continuous, a as discrete, ('e', 'i') as ['binary', 'continuous'] not supported
# The following setting with g as continuous, h as discrete, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with g as continuous, h as discrete, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with g as continuous, h as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with g as continuous, h as discrete, ('e', 'i') as ['binary', 'continuous'] not supported
# The following setting with i as continuous, a as discrete, ('j', 'd') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, a as discrete, ('j', 'b') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, a as discrete, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, a as discrete, ('j', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, a as discrete, ('j', 'c') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, a as discrete, ('j', 'h') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, a as discrete, ('d', 'b') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, a as discrete, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, a as discrete, ('d', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, a as discrete, ('d', 'c') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, a as discrete, ('d', 'h') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, a as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, a as discrete, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, a as discrete, ('b', 'g') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, a as discrete, ('b', 'c') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, a as discrete, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, a as discrete, ('e', 'g') as ['binary', 'continuous'] not supported
# The following setting with i as continuous, c as binary, ('j', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('j', 'a') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('j', 'h') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('d', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('d', 'h') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, c as binary, ('b', 'h') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('j', 'd') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, h as discrete, ('j', 'b') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, h as discrete, ('j', 'e') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, h as discrete, ('j', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('j', 'a') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('j', 'c') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, h as discrete, ('d', 'b') as ['continuous', 'continuous'] not supported
# The following setting with i as continuous, h as discrete, ('d', 'e') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, h as discrete, ('d', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('d', 'a') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('d', 'c') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, h as discrete, ('b', 'e') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, h as discrete, ('b', 'f') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('b', 'a') as ['continuous', 'discrete'] not supported
# The following setting with i as continuous, h as discrete, ('b', 'c') as ['continuous', 'binary'] not supported
# The following setting with i as continuous, h as discrete, ('e', 'g') as ['binary', 'continuous'] not supported

# %%
print(refuter_object)
# Out:
# Method name for discrete data:conditional_mutual_information
# Method name for continuous data:partial_correlation
# Number of conditional independencies entailed by model:359
# Number of independences satisfied by data:144
# Test passed:False
